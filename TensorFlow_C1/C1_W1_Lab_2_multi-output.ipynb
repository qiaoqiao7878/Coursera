# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 924us/sample - loss: 237.5328 - y1_output_loss: 118.1793 - y2_output_loss: 117.1874 - y1_output_root_mean_squared_error: 10.9223 - y2_output_root_mean_squared_error: 10.8737 - val_loss: 42.1974 - val_y1_output_loss: 15.0768 - val_y2_output_loss: 28.9876 - val_y1_output_root_mean_squared_error: 3.7788 - val_y2_output_root_mean_squared_error: 5.2837
# Epoch 2/500
# 614/614 [==============================] - 0s 134us/sample - loss: 31.1708 - y1_output_loss: 12.2493 - y2_output_loss: 18.7131 - y1_output_root_mean_squared_error: 3.5086 - y2_output_root_mean_squared_error: 4.3428 - val_loss: 24.3509 - val_y1_output_loss: 11.8605 - val_y2_output_loss: 13.5589 - val_y1_output_root_mean_squared_error: 3.3379 - val_y2_output_root_mean_squared_error: 3.6345
# Epoch 3/500
# 614/614 [==============================] - 0s 133us/sample - loss: 26.7765 - y1_output_loss: 10.2570 - y2_output_loss: 16.3491 - y1_output_root_mean_squared_error: 3.2129 - y2_output_root_mean_squared_error: 4.0563 - val_loss: 18.8764 - val_y1_output_loss: 9.1817 - val_y2_output_loss: 10.2282 - val_y1_output_root_mean_squared_error: 2.9522 - val_y2_output_root_mean_squared_error: 3.1876
# Epoch 4/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.5816 - y1_output_loss: 9.6107 - y2_output_loss: 14.1499 - y1_output_root_mean_squared_error: 3.0709 - y2_output_root_mean_squared_error: 3.7618 - val_loss: 30.8076 - val_y1_output_loss: 11.5148 - val_y2_output_loss: 18.8010 - val_y1_output_root_mean_squared_error: 3.4036 - val_y2_output_root_mean_squared_error: 4.3844
# Epoch 5/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.8724 - y1_output_loss: 9.0727 - y2_output_loss: 14.1122 - y1_output_root_mean_squared_error: 3.0070 - y2_output_root_mean_squared_error: 3.7189 - val_loss: 53.9769 - val_y1_output_loss: 13.1860 - val_y2_output_loss: 43.0705 - val_y1_output_root_mean_squared_error: 3.5325 - val_y2_output_root_mean_squared_error: 6.4419
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.5994 - y1_output_loss: 8.6999 - y2_output_loss: 13.7647 - y1_output_root_mean_squared_error: 2.9591 - y2_output_root_mean_squared_error: 3.7207 - val_loss: 19.4404 - val_y1_output_loss: 8.9159 - val_y2_output_loss: 10.6216 - val_y1_output_root_mean_squared_error: 2.9844 - val_y2_output_root_mean_squared_error: 3.2456
# Epoch 7/500
# 614/614 [==============================] - 0s 126us/sample - loss: 27.6958 - y1_output_loss: 9.8920 - y2_output_loss: 17.7703 - y1_output_root_mean_squared_error: 3.1417 - y2_output_root_mean_squared_error: 4.2220 - val_loss: 19.8621 - val_y1_output_loss: 9.5799 - val_y2_output_loss: 10.4709 - val_y1_output_root_mean_squared_error: 3.0514 - val_y2_output_root_mean_squared_error: 3.2483
# Epoch 8/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.8127 - y1_output_loss: 8.6467 - y2_output_loss: 13.5963 - y1_output_root_mean_squared_error: 2.9137 - y2_output_root_mean_squared_error: 3.6501 - val_loss: 34.3115 - val_y1_output_loss: 10.0008 - val_y2_output_loss: 23.6241 - val_y1_output_root_mean_squared_error: 3.1867 - val_y2_output_root_mean_squared_error: 4.9149
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.0110 - y1_output_loss: 8.0191 - y2_output_loss: 13.0233 - y1_output_root_mean_squared_error: 2.8214 - y2_output_root_mean_squared_error: 3.6125 - val_loss: 24.2680 - val_y1_output_loss: 10.4902 - val_y2_output_loss: 15.0408 - val_y1_output_root_mean_squared_error: 3.1482 - val_y2_output_root_mean_squared_error: 3.7890
# Epoch 10/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.6534 - y1_output_loss: 8.4414 - y2_output_loss: 13.1730 - y1_output_root_mean_squared_error: 2.9161 - y2_output_root_mean_squared_error: 3.6263 - val_loss: 25.3503 - val_y1_output_loss: 8.1719 - val_y2_output_loss: 16.8292 - val_y1_output_root_mean_squared_error: 2.8623 - val_y2_output_root_mean_squared_error: 4.1422
# Epoch 11/500
# 614/614 [==============================] - 0s 133us/sample - loss: 21.0098 - y1_output_loss: 8.1263 - y2_output_loss: 12.8113 - y1_output_root_mean_squared_error: 2.8507 - y2_output_root_mean_squared_error: 3.5893 - val_loss: 25.7448 - val_y1_output_loss: 10.9594 - val_y2_output_loss: 15.7780 - val_y1_output_root_mean_squared_error: 3.2243 - val_y2_output_root_mean_squared_error: 3.9178
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.9824 - y1_output_loss: 8.3466 - y2_output_loss: 14.7993 - y1_output_root_mean_squared_error: 2.8812 - y2_output_root_mean_squared_error: 3.8316 - val_loss: 17.8910 - val_y1_output_loss: 8.2218 - val_y2_output_loss: 10.0145 - val_y1_output_root_mean_squared_error: 2.8336 - val_y2_output_root_mean_squared_error: 3.1403
# Epoch 13/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.1692 - y1_output_loss: 7.8059 - y2_output_loss: 12.2645 - y1_output_root_mean_squared_error: 2.7983 - y2_output_root_mean_squared_error: 3.5127 - val_loss: 18.7783 - val_y1_output_loss: 8.7608 - val_y2_output_loss: 10.3825 - val_y1_output_root_mean_squared_error: 2.9268 - val_y2_output_root_mean_squared_error: 3.1957
# Epoch 14/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.5000 - y1_output_loss: 8.2327 - y2_output_loss: 13.3488 - y1_output_root_mean_squared_error: 2.8635 - y2_output_root_mean_squared_error: 3.6470 - val_loss: 24.2134 - val_y1_output_loss: 9.2542 - val_y2_output_loss: 15.8720 - val_y1_output_root_mean_squared_error: 2.9808 - val_y2_output_root_mean_squared_error: 3.9152
# Epoch 15/500
# 614/614 [==============================] - 0s 125us/sample - loss: 19.7690 - y1_output_loss: 7.8457 - y2_output_loss: 12.4026 - y1_output_root_mean_squared_error: 2.7457 - y2_output_root_mean_squared_error: 3.4972 - val_loss: 62.8857 - val_y1_output_loss: 18.6133 - val_y2_output_loss: 43.1680 - val_y1_output_root_mean_squared_error: 4.3765 - val_y2_output_root_mean_squared_error: 6.6130
# Epoch 16/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.7847 - y1_output_loss: 6.9817 - y2_output_loss: 11.8170 - y1_output_root_mean_squared_error: 2.6496 - y2_output_root_mean_squared_error: 3.4300 - val_loss: 39.9250 - val_y1_output_loss: 11.0340 - val_y2_output_loss: 28.5289 - val_y1_output_root_mean_squared_error: 3.3483 - val_y2_output_root_mean_squared_error: 5.3585
# Epoch 17/500
# 614/614 [==============================] - 0s 129us/sample - loss: 18.5165 - y1_output_loss: 7.0516 - y2_output_loss: 11.4739 - y1_output_root_mean_squared_error: 2.6600 - y2_output_root_mean_squared_error: 3.3824 - val_loss: 29.7407 - val_y1_output_loss: 9.5588 - val_y2_output_loss: 19.7255 - val_y1_output_root_mean_squared_error: 3.1111 - val_y2_output_root_mean_squared_error: 4.4791
# Epoch 18/500
# 614/614 [==============================] - 0s 125us/sample - loss: 17.3208 - y1_output_loss: 6.5672 - y2_output_loss: 10.6746 - y1_output_root_mean_squared_error: 2.5650 - y2_output_root_mean_squared_error: 3.2774 - val_loss: 16.0305 - val_y1_output_loss: 7.8012 - val_y2_output_loss: 8.1104 - val_y1_output_root_mean_squared_error: 2.8073 - val_y2_output_root_mean_squared_error: 2.8548
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 18.9047 - y1_output_loss: 6.7325 - y2_output_loss: 12.1249 - y1_output_root_mean_squared_error: 2.5880 - y2_output_root_mean_squared_error: 3.4939 - val_loss: 31.3724 - val_y1_output_loss: 12.4604 - val_y2_output_loss: 19.6441 - val_y1_output_root_mean_squared_error: 3.4932 - val_y2_output_root_mean_squared_error: 4.3783
# Epoch 20/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.8211 - y1_output_loss: 7.0933 - y2_output_loss: 10.8932 - y1_output_root_mean_squared_error: 2.6343 - y2_output_root_mean_squared_error: 3.2987 - val_loss: 32.6548 - val_y1_output_loss: 12.1651 - val_y2_output_loss: 19.9174 - val_y1_output_root_mean_squared_error: 3.5174 - val_y2_output_root_mean_squared_error: 4.5036
# Epoch 21/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.5114 - y1_output_loss: 6.5304 - y2_output_loss: 11.1087 - y1_output_root_mean_squared_error: 2.5496 - y2_output_root_mean_squared_error: 3.3183 - val_loss: 23.8735 - val_y1_output_loss: 9.6811 - val_y2_output_loss: 14.6435 - val_y1_output_root_mean_squared_error: 3.0876 - val_y2_output_root_mean_squared_error: 3.7868
# Epoch 22/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.4828 - y1_output_loss: 6.2275 - y2_output_loss: 10.3819 - y1_output_root_mean_squared_error: 2.4642 - y2_output_root_mean_squared_error: 3.2265 - val_loss: 22.0861 - val_y1_output_loss: 7.7623 - val_y2_output_loss: 13.7947 - val_y1_output_root_mean_squared_error: 2.8211 - val_y2_output_root_mean_squared_error: 3.7587
# Epoch 23/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.2097 - y1_output_loss: 5.3604 - y2_output_loss: 8.7989 - y1_output_root_mean_squared_error: 2.3211 - y2_output_root_mean_squared_error: 2.9702 - val_loss: 13.5204 - val_y1_output_loss: 5.6945 - val_y2_output_loss: 7.6919 - val_y1_output_root_mean_squared_error: 2.3940 - val_y2_output_root_mean_squared_error: 2.7909
# Epoch 24/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.0346 - y1_output_loss: 4.7614 - y2_output_loss: 8.2612 - y1_output_root_mean_squared_error: 2.1861 - y2_output_root_mean_squared_error: 2.8733 - val_loss: 19.4408 - val_y1_output_loss: 5.2169 - val_y2_output_loss: 14.4960 - val_y1_output_root_mean_squared_error: 2.2921 - val_y2_output_root_mean_squared_error: 3.7666
# Epoch 25/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.2647 - y1_output_loss: 5.2612 - y2_output_loss: 10.2560 - y1_output_root_mean_squared_error: 2.2843 - y2_output_root_mean_squared_error: 3.1697 - val_loss: 17.7000 - val_y1_output_loss: 6.0070 - val_y2_output_loss: 11.8800 - val_y1_output_root_mean_squared_error: 2.4441 - val_y2_output_root_mean_squared_error: 3.4244
# Epoch 26/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.6570 - y1_output_loss: 5.1149 - y2_output_loss: 9.5055 - y1_output_root_mean_squared_error: 2.2669 - y2_output_root_mean_squared_error: 3.0852 - val_loss: 13.9254 - val_y1_output_loss: 5.9701 - val_y2_output_loss: 7.9521 - val_y1_output_root_mean_squared_error: 2.4554 - val_y2_output_root_mean_squared_error: 2.8101
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.1434 - y1_output_loss: 4.3827 - y2_output_loss: 7.8445 - y1_output_root_mean_squared_error: 2.0954 - y2_output_root_mean_squared_error: 2.7844 - val_loss: 25.9713 - val_y1_output_loss: 5.7824 - val_y2_output_loss: 19.8746 - val_y1_output_root_mean_squared_error: 2.4396 - val_y2_output_root_mean_squared_error: 4.4743
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.6696 - y1_output_loss: 4.5297 - y2_output_loss: 9.1032 - y1_output_root_mean_squared_error: 2.1253 - y2_output_root_mean_squared_error: 3.0254 - val_loss: 19.7516 - val_y1_output_loss: 8.6823 - val_y2_output_loss: 11.2766 - val_y1_output_root_mean_squared_error: 2.9379 - val_y2_output_root_mean_squared_error: 3.3348
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.0321 - y1_output_loss: 4.0071 - y2_output_loss: 6.9745 - y1_output_root_mean_squared_error: 2.0056 - y2_output_root_mean_squared_error: 2.6476 - val_loss: 13.3078 - val_y1_output_loss: 4.7207 - val_y2_output_loss: 8.5800 - val_y1_output_root_mean_squared_error: 2.1819 - val_y2_output_root_mean_squared_error: 2.9235
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.3533 - y1_output_loss: 3.8976 - y2_output_loss: 7.5258 - y1_output_root_mean_squared_error: 1.9562 - y2_output_root_mean_squared_error: 2.7435 - val_loss: 23.5304 - val_y1_output_loss: 9.0359 - val_y2_output_loss: 14.4426 - val_y1_output_root_mean_squared_error: 3.0306 - val_y2_output_root_mean_squared_error: 3.7876
# Epoch 31/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.1036 - y1_output_loss: 3.5623 - y2_output_loss: 6.4534 - y1_output_root_mean_squared_error: 1.8953 - y2_output_root_mean_squared_error: 2.5517 - val_loss: 9.5713 - val_y1_output_loss: 4.2078 - val_y2_output_loss: 5.2551 - val_y1_output_root_mean_squared_error: 2.0669 - val_y2_output_root_mean_squared_error: 2.3020
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.8544 - y1_output_loss: 3.3694 - y2_output_loss: 6.4844 - y1_output_root_mean_squared_error: 1.8253 - y2_output_root_mean_squared_error: 2.5539 - val_loss: 11.6795 - val_y1_output_loss: 4.9181 - val_y2_output_loss: 6.7320 - val_y1_output_root_mean_squared_error: 2.2461 - val_y2_output_root_mean_squared_error: 2.5757
# Epoch 33/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.3077 - y1_output_loss: 3.4383 - y2_output_loss: 6.7971 - y1_output_root_mean_squared_error: 1.8594 - y2_output_root_mean_squared_error: 2.6173 - val_loss: 11.1414 - val_y1_output_loss: 4.1647 - val_y2_output_loss: 7.0743 - val_y1_output_root_mean_squared_error: 2.0441 - val_y2_output_root_mean_squared_error: 2.6387
# Epoch 34/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.0066 - y1_output_loss: 4.0378 - y2_output_loss: 8.0098 - y1_output_root_mean_squared_error: 2.0013 - y2_output_root_mean_squared_error: 2.8287 - val_loss: 9.6257 - val_y1_output_loss: 4.0222 - val_y2_output_loss: 5.6018 - val_y1_output_root_mean_squared_error: 2.0208 - val_y2_output_root_mean_squared_error: 2.3541
# Epoch 35/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.4896 - y1_output_loss: 3.1945 - y2_output_loss: 6.2584 - y1_output_root_mean_squared_error: 1.7932 - y2_output_root_mean_squared_error: 2.5048 - val_loss: 19.2772 - val_y1_output_loss: 4.5133 - val_y2_output_loss: 14.9224 - val_y1_output_root_mean_squared_error: 2.1435 - val_y2_output_root_mean_squared_error: 3.8318
# Epoch 36/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.5768 - y1_output_loss: 3.5013 - y2_output_loss: 8.0554 - y1_output_root_mean_squared_error: 1.8698 - y2_output_root_mean_squared_error: 2.8427 - val_loss: 11.9551 - val_y1_output_loss: 5.3917 - val_y2_output_loss: 6.4605 - val_y1_output_root_mean_squared_error: 2.3485 - val_y2_output_root_mean_squared_error: 2.5377
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.1826 - y1_output_loss: 3.3064 - y2_output_loss: 5.8010 - y1_output_root_mean_squared_error: 1.8244 - y2_output_root_mean_squared_error: 2.4196 - val_loss: 8.5563 - val_y1_output_loss: 3.4159 - val_y2_output_loss: 5.2051 - val_y1_output_root_mean_squared_error: 1.8764 - val_y2_output_root_mean_squared_error: 2.2440
# Epoch 38/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.9370 - y1_output_loss: 2.8319 - y2_output_loss: 6.0498 - y1_output_root_mean_squared_error: 1.6885 - y2_output_root_mean_squared_error: 2.4670 - val_loss: 7.9381 - val_y1_output_loss: 3.0416 - val_y2_output_loss: 4.9645 - val_y1_output_root_mean_squared_error: 1.7641 - val_y2_output_root_mean_squared_error: 2.1968
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8952 - y1_output_loss: 2.5841 - y2_output_loss: 5.3035 - y1_output_root_mean_squared_error: 1.6067 - y2_output_root_mean_squared_error: 2.3052 - val_loss: 11.1000 - val_y1_output_loss: 3.5559 - val_y2_output_loss: 7.6111 - val_y1_output_root_mean_squared_error: 1.9160 - val_y2_output_root_mean_squared_error: 2.7256
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.2266 - y1_output_loss: 2.8682 - y2_output_loss: 6.3850 - y1_output_root_mean_squared_error: 1.6820 - y2_output_root_mean_squared_error: 2.5293 - val_loss: 9.4049 - val_y1_output_loss: 4.2893 - val_y2_output_loss: 5.2391 - val_y1_output_root_mean_squared_error: 2.0881 - val_y2_output_root_mean_squared_error: 2.2461
# Epoch 41/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.9848 - y1_output_loss: 2.4859 - y2_output_loss: 5.4442 - y1_output_root_mean_squared_error: 1.5825 - y2_output_root_mean_squared_error: 2.3411 - val_loss: 7.7410 - val_y1_output_loss: 3.0350 - val_y2_output_loss: 4.7046 - val_y1_output_root_mean_squared_error: 1.7652 - val_y2_output_root_mean_squared_error: 2.1506
# Epoch 42/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.5542 - y1_output_loss: 2.8106 - y2_output_loss: 5.6945 - y1_output_root_mean_squared_error: 1.6786 - y2_output_root_mean_squared_error: 2.3951 - val_loss: 8.7689 - val_y1_output_loss: 3.9129 - val_y2_output_loss: 5.0437 - val_y1_output_root_mean_squared_error: 1.9818 - val_y2_output_root_mean_squared_error: 2.2003
# Epoch 43/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.7654 - y1_output_loss: 2.5439 - y2_output_loss: 5.2348 - y1_output_root_mean_squared_error: 1.5986 - y2_output_root_mean_squared_error: 2.2825 - val_loss: 8.8412 - val_y1_output_loss: 3.1798 - val_y2_output_loss: 5.7909 - val_y1_output_root_mean_squared_error: 1.8096 - val_y2_output_root_mean_squared_error: 2.3593
# Epoch 44/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.9857 - y1_output_loss: 2.4876 - y2_output_loss: 5.5003 - y1_output_root_mean_squared_error: 1.5760 - y2_output_root_mean_squared_error: 2.3456 - val_loss: 20.7339 - val_y1_output_loss: 6.6915 - val_y2_output_loss: 14.0245 - val_y1_output_root_mean_squared_error: 2.6300 - val_y2_output_root_mean_squared_error: 3.7171
# Epoch 45/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.5271 - y1_output_loss: 2.2516 - y2_output_loss: 5.2775 - y1_output_root_mean_squared_error: 1.5022 - y2_output_root_mean_squared_error: 2.2957 - val_loss: 21.1933 - val_y1_output_loss: 5.0274 - val_y2_output_loss: 16.3791 - val_y1_output_root_mean_squared_error: 2.2630 - val_y2_output_root_mean_squared_error: 4.0090
# Epoch 46/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.7643 - y1_output_loss: 2.4038 - y2_output_loss: 5.3759 - y1_output_root_mean_squared_error: 1.5521 - y2_output_root_mean_squared_error: 2.3141 - val_loss: 8.4705 - val_y1_output_loss: 2.5280 - val_y2_output_loss: 6.0767 - val_y1_output_root_mean_squared_error: 1.6153 - val_y2_output_root_mean_squared_error: 2.4210
# Epoch 47/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.1114 - y1_output_loss: 2.4612 - y2_output_loss: 5.6906 - y1_output_root_mean_squared_error: 1.5535 - y2_output_root_mean_squared_error: 2.3871 - val_loss: 25.7619 - val_y1_output_loss: 10.9634 - val_y2_output_loss: 14.8046 - val_y1_output_root_mean_squared_error: 3.3265 - val_y2_output_root_mean_squared_error: 3.8336
# Epoch 48/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.2414 - y1_output_loss: 2.3628 - y2_output_loss: 5.8143 - y1_output_root_mean_squared_error: 1.5441 - y2_output_root_mean_squared_error: 2.4202 - val_loss: 7.9132 - val_y1_output_loss: 3.1313 - val_y2_output_loss: 4.8582 - val_y1_output_root_mean_squared_error: 1.7909 - val_y2_output_root_mean_squared_error: 2.1693
# Epoch 49/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.9255 - y1_output_loss: 2.4420 - y2_output_loss: 5.5588 - y1_output_root_mean_squared_error: 1.5521 - y2_output_root_mean_squared_error: 2.3487 - val_loss: 11.9465 - val_y1_output_loss: 4.5671 - val_y2_output_loss: 7.4218 - val_y1_output_root_mean_squared_error: 2.1520 - val_y2_output_root_mean_squared_error: 2.7047
# Epoch 50/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.8864 - y1_output_loss: 2.3540 - y2_output_loss: 5.4898 - y1_output_root_mean_squared_error: 1.5379 - y2_output_root_mean_squared_error: 2.3497 - val_loss: 9.4046 - val_y1_output_loss: 3.3098 - val_y2_output_loss: 6.2359 - val_y1_output_root_mean_squared_error: 1.8283 - val_y2_output_root_mean_squared_error: 2.4621
# Epoch 51/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.7464 - y1_output_loss: 2.3547 - y2_output_loss: 5.3898 - y1_output_root_mean_squared_error: 1.5327 - y2_output_root_mean_squared_error: 2.3232 - val_loss: 10.0937 - val_y1_output_loss: 3.3685 - val_y2_output_loss: 6.9529 - val_y1_output_root_mean_squared_error: 1.8341 - val_y2_output_root_mean_squared_error: 2.5942
# Epoch 52/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.4331 - y1_output_loss: 1.9996 - y2_output_loss: 4.4721 - y1_output_root_mean_squared_error: 1.4175 - y2_output_root_mean_squared_error: 2.1033 - val_loss: 7.1235 - val_y1_output_loss: 2.8146 - val_y2_output_loss: 4.3672 - val_y1_output_root_mean_squared_error: 1.6943 - val_y2_output_root_mean_squared_error: 2.0623
# Epoch 53/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.9460 - y1_output_loss: 2.9761 - y2_output_loss: 6.9232 - y1_output_root_mean_squared_error: 1.7254 - y2_output_root_mean_squared_error: 2.6399 - val_loss: 9.9698 - val_y1_output_loss: 3.2217 - val_y2_output_loss: 6.9610 - val_y1_output_root_mean_squared_error: 1.8086 - val_y2_output_root_mean_squared_error: 2.5882
# Epoch 54/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.7830 - y1_output_loss: 1.9903 - y2_output_loss: 4.8121 - y1_output_root_mean_squared_error: 1.4141 - y2_output_root_mean_squared_error: 2.1871 - val_loss: 13.1014 - val_y1_output_loss: 3.4479 - val_y2_output_loss: 9.8447 - val_y1_output_root_mean_squared_error: 1.8621 - val_y2_output_root_mean_squared_error: 3.1039
# Epoch 55/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.5637 - y1_output_loss: 1.7459 - y2_output_loss: 3.7910 - y1_output_root_mean_squared_error: 1.3269 - y2_output_root_mean_squared_error: 1.9501 - val_loss: 12.1338 - val_y1_output_loss: 3.2697 - val_y2_output_loss: 9.1663 - val_y1_output_root_mean_squared_error: 1.8184 - val_y2_output_root_mean_squared_error: 2.9711
# Epoch 56/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.4802 - y1_output_loss: 1.9416 - y2_output_loss: 4.4905 - y1_output_root_mean_squared_error: 1.3965 - y2_output_root_mean_squared_error: 2.1284 - val_loss: 5.7936 - val_y1_output_loss: 1.9995 - val_y2_output_loss: 3.9382 - val_y1_output_root_mean_squared_error: 1.4330 - val_y2_output_root_mean_squared_error: 1.9339
# Epoch 57/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.9288 - y1_output_loss: 1.7314 - y2_output_loss: 4.1789 - y1_output_root_mean_squared_error: 1.3083 - y2_output_root_mean_squared_error: 2.0535 - val_loss: 6.7418 - val_y1_output_loss: 2.5073 - val_y2_output_loss: 4.4288 - val_y1_output_root_mean_squared_error: 1.6014 - val_y2_output_root_mean_squared_error: 2.0439
# Epoch 58/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.8200 - y1_output_loss: 1.8382 - y2_output_loss: 4.0157 - y1_output_root_mean_squared_error: 1.3452 - y2_output_root_mean_squared_error: 2.0026 - val_loss: 8.4436 - val_y1_output_loss: 3.0154 - val_y2_output_loss: 5.6112 - val_y1_output_root_mean_squared_error: 1.7405 - val_y2_output_root_mean_squared_error: 2.3268
# Epoch 59/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.3343 - y1_output_loss: 1.5892 - y2_output_loss: 3.6965 - y1_output_root_mean_squared_error: 1.2664 - y2_output_root_mean_squared_error: 1.9314 - val_loss: 5.9260 - val_y1_output_loss: 2.0772 - val_y2_output_loss: 4.0192 - val_y1_output_root_mean_squared_error: 1.4589 - val_y2_output_root_mean_squared_error: 1.9488
# Epoch 60/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.4577 - y1_output_loss: 1.9227 - y2_output_loss: 4.4888 - y1_output_root_mean_squared_error: 1.3922 - y2_output_root_mean_squared_error: 2.1259 - val_loss: 6.6731 - val_y1_output_loss: 2.4030 - val_y2_output_loss: 4.3972 - val_y1_output_root_mean_squared_error: 1.5653 - val_y2_output_root_mean_squared_error: 2.0550
# Epoch 61/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.8709 - y1_output_loss: 2.1251 - y2_output_loss: 4.7223 - y1_output_root_mean_squared_error: 1.4593 - y2_output_root_mean_squared_error: 2.1775 - val_loss: 7.6014 - val_y1_output_loss: 2.3287 - val_y2_output_loss: 5.3684 - val_y1_output_root_mean_squared_error: 1.5410 - val_y2_output_root_mean_squared_error: 2.2862
# Epoch 62/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.8821 - y1_output_loss: 1.6673 - y2_output_loss: 4.1849 - y1_output_root_mean_squared_error: 1.2954 - y2_output_root_mean_squared_error: 2.0504 - val_loss: 7.1503 - val_y1_output_loss: 2.4439 - val_y2_output_loss: 4.9071 - val_y1_output_root_mean_squared_error: 1.5667 - val_y2_output_root_mean_squared_error: 2.1670
# Epoch 63/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.7309 - y1_output_loss: 1.6522 - y2_output_loss: 4.0780 - y1_output_root_mean_squared_error: 1.2864 - y2_output_root_mean_squared_error: 2.0189 - val_loss: 5.2905 - val_y1_output_loss: 1.7084 - val_y2_output_loss: 3.7102 - val_y1_output_root_mean_squared_error: 1.3202 - val_y2_output_root_mean_squared_error: 1.8835
# Epoch 64/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.0680 - y1_output_loss: 1.7653 - y2_output_loss: 4.2670 - y1_output_root_mean_squared_error: 1.3307 - y2_output_root_mean_squared_error: 2.0730 - val_loss: 5.0831 - val_y1_output_loss: 1.7482 - val_y2_output_loss: 3.4139 - val_y1_output_root_mean_squared_error: 1.3341 - val_y2_output_root_mean_squared_error: 1.8175
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.3692 - y1_output_loss: 1.5509 - y2_output_loss: 3.7784 - y1_output_root_mean_squared_error: 1.2471 - y2_output_root_mean_squared_error: 1.9530 - val_loss: 5.3136 - val_y1_output_loss: 1.5036 - val_y2_output_loss: 4.0174 - val_y1_output_root_mean_squared_error: 1.2454 - val_y2_output_root_mean_squared_error: 1.9398
# Epoch 66/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.9940 - y1_output_loss: 1.3298 - y2_output_loss: 3.6278 - y1_output_root_mean_squared_error: 1.1571 - y2_output_root_mean_squared_error: 1.9119 - val_loss: 5.2892 - val_y1_output_loss: 1.7818 - val_y2_output_loss: 3.5916 - val_y1_output_root_mean_squared_error: 1.3438 - val_y2_output_root_mean_squared_error: 1.8664
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.0937 - y1_output_loss: 1.4215 - y2_output_loss: 3.6527 - y1_output_root_mean_squared_error: 1.1888 - y2_output_root_mean_squared_error: 1.9184 - val_loss: 8.5946 - val_y1_output_loss: 2.7256 - val_y2_output_loss: 5.9205 - val_y1_output_root_mean_squared_error: 1.6613 - val_y2_output_root_mean_squared_error: 2.4155
# Epoch 68/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.5168 - y1_output_loss: 1.6516 - y2_output_loss: 4.1988 - y1_output_root_mean_squared_error: 1.2598 - y2_output_root_mean_squared_error: 1.9824 - val_loss: 216.3556 - val_y1_output_loss: 88.2439 - val_y2_output_loss: 124.9605 - val_y1_output_root_mean_squared_error: 9.4803 - val_y2_output_root_mean_squared_error: 11.2463
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.3532 - y1_output_loss: 4.0188 - y2_output_loss: 7.2836 - y1_output_root_mean_squared_error: 2.0077 - y2_output_root_mean_squared_error: 2.7060 - val_loss: 7.0684 - val_y1_output_loss: 2.4542 - val_y2_output_loss: 4.7168 - val_y1_output_root_mean_squared_error: 1.5809 - val_y2_output_root_mean_squared_error: 2.1376
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.9036 - y1_output_loss: 1.3989 - y2_output_loss: 3.4857 - y1_output_root_mean_squared_error: 1.1820 - y2_output_root_mean_squared_error: 1.8725 - val_loss: 6.1580 - val_y1_output_loss: 1.7878 - val_y2_output_loss: 4.4782 - val_y1_output_root_mean_squared_error: 1.3558 - val_y2_output_root_mean_squared_error: 2.0784
# Epoch 71/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.6383 - y1_output_loss: 1.2030 - y2_output_loss: 3.4186 - y1_output_root_mean_squared_error: 1.0979 - y2_output_root_mean_squared_error: 1.8528 - val_loss: 4.7783 - val_y1_output_loss: 1.5055 - val_y2_output_loss: 3.3922 - val_y1_output_root_mean_squared_error: 1.2394 - val_y2_output_root_mean_squared_error: 1.8006
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1758 - y1_output_loss: 1.4669 - y2_output_loss: 3.6764 - y1_output_root_mean_squared_error: 1.2112 - y2_output_root_mean_squared_error: 1.9258 - val_loss: 4.8541 - val_y1_output_loss: 1.5620 - val_y2_output_loss: 3.4174 - val_y1_output_root_mean_squared_error: 1.2685 - val_y2_output_root_mean_squared_error: 1.8014
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.1461 - y1_output_loss: 1.1244 - y2_output_loss: 3.0315 - y1_output_root_mean_squared_error: 1.0477 - y2_output_root_mean_squared_error: 1.7460 - val_loss: 4.5329 - val_y1_output_loss: 1.2858 - val_y2_output_loss: 3.3832 - val_y1_output_root_mean_squared_error: 1.1455 - val_y2_output_root_mean_squared_error: 1.7946
# Epoch 74/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.3740 - y1_output_loss: 1.1635 - y2_output_loss: 4.1996 - y1_output_root_mean_squared_error: 1.0802 - y2_output_root_mean_squared_error: 2.0511 - val_loss: 6.0415 - val_y1_output_loss: 1.3963 - val_y2_output_loss: 4.8394 - val_y1_output_root_mean_squared_error: 1.1908 - val_y2_output_root_mean_squared_error: 2.1503
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9911 - y1_output_loss: 1.0442 - y2_output_loss: 2.9137 - y1_output_root_mean_squared_error: 1.0245 - y2_output_root_mean_squared_error: 1.7151 - val_loss: 4.0329 - val_y1_output_loss: 1.1574 - val_y2_output_loss: 3.0023 - val_y1_output_root_mean_squared_error: 1.0888 - val_y2_output_root_mean_squared_error: 1.6874
# Epoch 76/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.9017 - y1_output_loss: 1.0958 - y2_output_loss: 2.7867 - y1_output_root_mean_squared_error: 1.0457 - y2_output_root_mean_squared_error: 1.6758 - val_loss: 3.8573 - val_y1_output_loss: 1.2851 - val_y2_output_loss: 2.7117 - val_y1_output_root_mean_squared_error: 1.1398 - val_y2_output_root_mean_squared_error: 1.5994
# Epoch 77/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.7593 - y1_output_loss: 1.2312 - y2_output_loss: 3.4889 - y1_output_root_mean_squared_error: 1.1124 - y2_output_root_mean_squared_error: 1.8766 - val_loss: 3.4684 - val_y1_output_loss: 0.8304 - val_y2_output_loss: 2.8007 - val_y1_output_root_mean_squared_error: 0.9236 - val_y2_output_root_mean_squared_error: 1.6172
# Epoch 78/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3401 - y1_output_loss: 1.3859 - y2_output_loss: 3.9271 - y1_output_root_mean_squared_error: 1.1812 - y2_output_root_mean_squared_error: 1.9862 - val_loss: 4.3445 - val_y1_output_loss: 0.8582 - val_y2_output_loss: 3.6566 - val_y1_output_root_mean_squared_error: 0.9370 - val_y2_output_root_mean_squared_error: 1.8618
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.1575 - y1_output_loss: 1.0156 - y2_output_loss: 3.1623 - y1_output_root_mean_squared_error: 1.0007 - y2_output_root_mean_squared_error: 1.7765 - val_loss: 11.4491 - val_y1_output_loss: 3.4195 - val_y2_output_loss: 8.0069 - val_y1_output_root_mean_squared_error: 1.8607 - val_y2_output_root_mean_squared_error: 2.8261
# Epoch 80/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0498 - y1_output_loss: 0.8129 - y2_output_loss: 3.2021 - y1_output_root_mean_squared_error: 0.9057 - y2_output_root_mean_squared_error: 1.7971 - val_loss: 3.3057 - val_y1_output_loss: 1.0369 - val_y2_output_loss: 2.3868 - val_y1_output_root_mean_squared_error: 1.0276 - val_y2_output_root_mean_squared_error: 1.4999
# Epoch 81/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.5826 - y1_output_loss: 0.8333 - y2_output_loss: 2.7503 - y1_output_root_mean_squared_error: 0.9167 - y2_output_root_mean_squared_error: 1.6560 - val_loss: 5.6980 - val_y1_output_loss: 1.0341 - val_y2_output_loss: 4.8644 - val_y1_output_root_mean_squared_error: 1.0086 - val_y2_output_root_mean_squared_error: 2.1635
# Epoch 82/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1186 - y1_output_loss: 0.7719 - y2_output_loss: 2.4066 - y1_output_root_mean_squared_error: 0.8735 - y2_output_root_mean_squared_error: 1.5348 - val_loss: 10.9461 - val_y1_output_loss: 3.1502 - val_y2_output_loss: 7.8408 - val_y1_output_root_mean_squared_error: 1.7934 - val_y2_output_root_mean_squared_error: 2.7803
# Epoch 83/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.1356 - y1_output_loss: 0.8279 - y2_output_loss: 2.3511 - y1_output_root_mean_squared_error: 0.9122 - y2_output_root_mean_squared_error: 1.5178 - val_loss: 11.7728 - val_y1_output_loss: 1.8381 - val_y2_output_loss: 10.0488 - val_y1_output_root_mean_squared_error: 1.3630 - val_y2_output_root_mean_squared_error: 3.1488
# Epoch 84/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.3928 - y1_output_loss: 0.9370 - y2_output_loss: 3.4403 - y1_output_root_mean_squared_error: 0.9666 - y2_output_root_mean_squared_error: 1.8597 - val_loss: 4.6731 - val_y1_output_loss: 1.5418 - val_y2_output_loss: 3.2081 - val_y1_output_root_mean_squared_error: 1.2589 - val_y2_output_root_mean_squared_error: 1.7573
# Epoch 85/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8661 - y1_output_loss: 1.0008 - y2_output_loss: 2.8559 - y1_output_root_mean_squared_error: 1.0004 - y2_output_root_mean_squared_error: 1.6927 - val_loss: 2.7891 - val_y1_output_loss: 0.6943 - val_y2_output_loss: 2.1637 - val_y1_output_root_mean_squared_error: 0.8341 - val_y2_output_root_mean_squared_error: 1.4469
# Epoch 86/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7243 - y1_output_loss: 1.2412 - y2_output_loss: 3.4952 - y1_output_root_mean_squared_error: 1.1189 - y2_output_root_mean_squared_error: 1.8634 - val_loss: 7.5228 - val_y1_output_loss: 0.8347 - val_y2_output_loss: 6.9771 - val_y1_output_root_mean_squared_error: 0.9147 - val_y2_output_root_mean_squared_error: 2.5857
# Epoch 87/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1237 - y1_output_loss: 0.6526 - y2_output_loss: 2.4452 - y1_output_root_mean_squared_error: 0.8114 - y2_output_root_mean_squared_error: 1.5702 - val_loss: 2.9275 - val_y1_output_loss: 0.8809 - val_y2_output_loss: 2.1466 - val_y1_output_root_mean_squared_error: 0.9288 - val_y2_output_root_mean_squared_error: 1.4370
# Epoch 88/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9267 - y1_output_loss: 0.6629 - y2_output_loss: 2.2799 - y1_output_root_mean_squared_error: 0.8101 - y2_output_root_mean_squared_error: 1.5068 - val_loss: 3.2498 - val_y1_output_loss: 1.0827 - val_y2_output_loss: 2.3088 - val_y1_output_root_mean_squared_error: 1.0542 - val_y2_output_root_mean_squared_error: 1.4624
# Epoch 89/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0274 - y1_output_loss: 0.7805 - y2_output_loss: 2.2263 - y1_output_root_mean_squared_error: 0.8859 - y2_output_root_mean_squared_error: 1.4975 - val_loss: 2.9531 - val_y1_output_loss: 0.6539 - val_y2_output_loss: 2.3921 - val_y1_output_root_mean_squared_error: 0.8063 - val_y2_output_root_mean_squared_error: 1.5176
# Epoch 90/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2107 - y1_output_loss: 0.7652 - y2_output_loss: 2.4416 - y1_output_root_mean_squared_error: 0.8756 - y2_output_root_mean_squared_error: 1.5633 - val_loss: 5.0752 - val_y1_output_loss: 0.4889 - val_y2_output_loss: 4.7668 - val_y1_output_root_mean_squared_error: 0.6975 - val_y2_output_root_mean_squared_error: 2.1421
# Epoch 91/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.7648 - y1_output_loss: 0.5912 - y2_output_loss: 2.1971 - y1_output_root_mean_squared_error: 0.7691 - y2_output_root_mean_squared_error: 1.4742 - val_loss: 8.9200 - val_y1_output_loss: 1.8511 - val_y2_output_loss: 7.2844 - val_y1_output_root_mean_squared_error: 1.3759 - val_y2_output_root_mean_squared_error: 2.6509
# Epoch 92/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.6399 - y1_output_loss: 0.6764 - y2_output_loss: 1.9626 - y1_output_root_mean_squared_error: 0.8228 - y2_output_root_mean_squared_error: 1.4010 - val_loss: 2.9463 - val_y1_output_loss: 0.6219 - val_y2_output_loss: 2.4504 - val_y1_output_root_mean_squared_error: 0.8008 - val_y2_output_root_mean_squared_error: 1.5182
# Epoch 93/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.4286 - y1_output_loss: 0.7196 - y2_output_loss: 2.8522 - y1_output_root_mean_squared_error: 0.8394 - y2_output_root_mean_squared_error: 1.6504 - val_loss: 12.6575 - val_y1_output_loss: 2.6362 - val_y2_output_loss: 10.0923 - val_y1_output_root_mean_squared_error: 1.6347 - val_y2_output_root_mean_squared_error: 3.1600
# Epoch 94/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0140 - y1_output_loss: 0.7673 - y2_output_loss: 2.2295 - y1_output_root_mean_squared_error: 0.8792 - y2_output_root_mean_squared_error: 1.4970 - val_loss: 3.2609 - val_y1_output_loss: 0.6601 - val_y2_output_loss: 2.7019 - val_y1_output_root_mean_squared_error: 0.8162 - val_y2_output_root_mean_squared_error: 1.6108
# Epoch 95/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0570 - y1_output_loss: 0.7584 - y2_output_loss: 2.2846 - y1_output_root_mean_squared_error: 0.8703 - y2_output_root_mean_squared_error: 1.5164 - val_loss: 2.6881 - val_y1_output_loss: 0.6349 - val_y2_output_loss: 2.1814 - val_y1_output_root_mean_squared_error: 0.8013 - val_y2_output_root_mean_squared_error: 1.4304
# Epoch 96/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.8336 - y1_output_loss: 0.6563 - y2_output_loss: 2.1789 - y1_output_root_mean_squared_error: 0.8073 - y2_output_root_mean_squared_error: 1.4771 - val_loss: 2.6579 - val_y1_output_loss: 0.5594 - val_y2_output_loss: 2.1925 - val_y1_output_root_mean_squared_error: 0.7370 - val_y2_output_root_mean_squared_error: 1.4542
# Epoch 97/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0526 - y1_output_loss: 1.0165 - y2_output_loss: 3.0050 - y1_output_root_mean_squared_error: 1.0113 - y2_output_root_mean_squared_error: 1.7406 - val_loss: 3.5490 - val_y1_output_loss: 0.9603 - val_y2_output_loss: 2.7798 - val_y1_output_root_mean_squared_error: 0.9605 - val_y2_output_root_mean_squared_error: 1.6206
# Epoch 98/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9819 - y1_output_loss: 0.6798 - y2_output_loss: 2.2875 - y1_output_root_mean_squared_error: 0.8215 - y2_output_root_mean_squared_error: 1.5189 - val_loss: 4.0337 - val_y1_output_loss: 1.2753 - val_y2_output_loss: 2.7629 - val_y1_output_root_mean_squared_error: 1.1367 - val_y2_output_root_mean_squared_error: 1.6558
# Epoch 99/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5806 - y1_output_loss: 1.5100 - y2_output_loss: 4.1147 - y1_output_root_mean_squared_error: 1.2274 - y2_output_root_mean_squared_error: 2.0185 - val_loss: 8.1120 - val_y1_output_loss: 3.6157 - val_y2_output_loss: 4.4232 - val_y1_output_root_mean_squared_error: 1.9144 - val_y2_output_root_mean_squared_error: 2.1088
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2007 - y1_output_loss: 0.7950 - y2_output_loss: 2.3800 - y1_output_root_mean_squared_error: 0.8957 - y2_output_root_mean_squared_error: 1.5487 - val_loss: 2.8720 - val_y1_output_loss: 0.5963 - val_y2_output_loss: 2.4298 - val_y1_output_root_mean_squared_error: 0.7606 - val_y2_output_root_mean_squared_error: 1.5144
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1694 - y1_output_loss: 0.8052 - y2_output_loss: 2.3425 - y1_output_root_mean_squared_error: 0.8998 - y2_output_root_mean_squared_error: 1.5361 - val_loss: 5.3390 - val_y1_output_loss: 1.8718 - val_y2_output_loss: 3.7123 - val_y1_output_root_mean_squared_error: 1.3529 - val_y2_output_root_mean_squared_error: 1.8732
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0553 - y1_output_loss: 0.7055 - y2_output_loss: 2.3410 - y1_output_root_mean_squared_error: 0.8378 - y2_output_root_mean_squared_error: 1.5341 - val_loss: 2.6837 - val_y1_output_loss: 0.4039 - val_y2_output_loss: 2.4360 - val_y1_output_root_mean_squared_error: 0.6363 - val_y2_output_root_mean_squared_error: 1.5096
# Epoch 103/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2217 - y1_output_loss: 0.6660 - y2_output_loss: 2.5921 - y1_output_root_mean_squared_error: 0.8187 - y2_output_root_mean_squared_error: 1.5973 - val_loss: 3.0799 - val_y1_output_loss: 0.4370 - val_y2_output_loss: 2.7152 - val_y1_output_root_mean_squared_error: 0.6659 - val_y2_output_root_mean_squared_error: 1.6237
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6779 - y1_output_loss: 0.8790 - y2_output_loss: 2.8040 - y1_output_root_mean_squared_error: 0.9405 - y2_output_root_mean_squared_error: 1.6713 - val_loss: 3.8120 - val_y1_output_loss: 0.6039 - val_y2_output_loss: 3.2597 - val_y1_output_root_mean_squared_error: 0.7763 - val_y2_output_root_mean_squared_error: 1.7915
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5615 - y1_output_loss: 0.5351 - y2_output_loss: 2.0695 - y1_output_root_mean_squared_error: 0.7333 - y2_output_root_mean_squared_error: 1.4226 - val_loss: 2.4238 - val_y1_output_loss: 0.5271 - val_y2_output_loss: 2.0663 - val_y1_output_root_mean_squared_error: 0.7335 - val_y2_output_root_mean_squared_error: 1.3732
# Epoch 106/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6525 - y1_output_loss: 0.6223 - y2_output_loss: 2.0145 - y1_output_root_mean_squared_error: 0.7878 - y2_output_root_mean_squared_error: 1.4255 - val_loss: 2.1121 - val_y1_output_loss: 0.4099 - val_y2_output_loss: 1.7779 - val_y1_output_root_mean_squared_error: 0.6387 - val_y2_output_root_mean_squared_error: 1.3054
# Epoch 107/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.0722 - y1_output_loss: 0.4673 - y2_output_loss: 1.5951 - y1_output_root_mean_squared_error: 0.6845 - y2_output_root_mean_squared_error: 1.2664 - val_loss: 3.3717 - val_y1_output_loss: 0.8364 - val_y2_output_loss: 2.6995 - val_y1_output_root_mean_squared_error: 0.9192 - val_y2_output_root_mean_squared_error: 1.5895
# Epoch 108/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.2305 - y1_output_loss: 0.5447 - y2_output_loss: 1.6730 - y1_output_root_mean_squared_error: 0.7401 - y2_output_root_mean_squared_error: 1.2972 - val_loss: 2.6786 - val_y1_output_loss: 0.5718 - val_y2_output_loss: 2.1460 - val_y1_output_root_mean_squared_error: 0.7621 - val_y2_output_root_mean_squared_error: 1.4484
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4683 - y1_output_loss: 0.5058 - y2_output_loss: 1.9497 - y1_output_root_mean_squared_error: 0.7144 - y2_output_root_mean_squared_error: 1.3993 - val_loss: 2.6646 - val_y1_output_loss: 0.5266 - val_y2_output_loss: 2.2295 - val_y1_output_root_mean_squared_error: 0.7299 - val_y2_output_root_mean_squared_error: 1.4601
# Epoch 110/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5223 - y1_output_loss: 0.5965 - y2_output_loss: 1.9052 - y1_output_root_mean_squared_error: 0.7759 - y2_output_root_mean_squared_error: 1.3857 - val_loss: 1.9725 - val_y1_output_loss: 0.3360 - val_y2_output_loss: 1.7262 - val_y1_output_root_mean_squared_error: 0.5765 - val_y2_output_root_mean_squared_error: 1.2807
# Epoch 111/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.0859 - y1_output_loss: 0.5093 - y2_output_loss: 1.5592 - y1_output_root_mean_squared_error: 0.7164 - y2_output_root_mean_squared_error: 1.2541 - val_loss: 2.1703 - val_y1_output_loss: 0.4078 - val_y2_output_loss: 1.8714 - val_y1_output_root_mean_squared_error: 0.6395 - val_y2_output_root_mean_squared_error: 1.3272
# Epoch 112/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.0819 - y1_output_loss: 0.5182 - y2_output_loss: 1.5717 - y1_output_root_mean_squared_error: 0.7214 - y2_output_root_mean_squared_error: 1.2496 - val_loss: 4.5607 - val_y1_output_loss: 0.6287 - val_y2_output_loss: 4.1427 - val_y1_output_root_mean_squared_error: 0.7757 - val_y2_output_root_mean_squared_error: 1.9897
# Epoch 113/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8035 - y1_output_loss: 0.6226 - y2_output_loss: 2.2155 - y1_output_root_mean_squared_error: 0.7892 - y2_output_root_mean_squared_error: 1.4767 - val_loss: 6.9853 - val_y1_output_loss: 1.8753 - val_y2_output_loss: 5.1191 - val_y1_output_root_mean_squared_error: 1.3669 - val_y2_output_root_mean_squared_error: 2.2620
# Epoch 114/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.0988 - y1_output_loss: 1.0460 - y2_output_loss: 3.0258 - y1_output_root_mean_squared_error: 1.0221 - y2_output_root_mean_squared_error: 1.7476 - val_loss: 2.8710 - val_y1_output_loss: 0.4540 - val_y2_output_loss: 2.5944 - val_y1_output_root_mean_squared_error: 0.6810 - val_y2_output_root_mean_squared_error: 1.5515
# Epoch 115/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5260 - y1_output_loss: 0.6261 - y2_output_loss: 1.8806 - y1_output_root_mean_squared_error: 0.7944 - y2_output_root_mean_squared_error: 1.3765 - val_loss: 1.9928 - val_y1_output_loss: 0.3777 - val_y2_output_loss: 1.7015 - val_y1_output_root_mean_squared_error: 0.6222 - val_y2_output_root_mean_squared_error: 1.2672
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.2595 - y1_output_loss: 0.5695 - y2_output_loss: 1.6923 - y1_output_root_mean_squared_error: 0.7563 - y2_output_root_mean_squared_error: 1.2991 - val_loss: 1.8857 - val_y1_output_loss: 0.3693 - val_y2_output_loss: 1.6189 - val_y1_output_root_mean_squared_error: 0.6097 - val_y2_output_root_mean_squared_error: 1.2304
# Epoch 117/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6222 - y1_output_loss: 0.5719 - y2_output_loss: 2.0507 - y1_output_root_mean_squared_error: 0.7580 - y2_output_root_mean_squared_error: 1.4309 - val_loss: 2.6754 - val_y1_output_loss: 0.6595 - val_y2_output_loss: 2.0749 - val_y1_output_root_mean_squared_error: 0.8201 - val_y2_output_root_mean_squared_error: 1.4152
# Epoch 118/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8416 - y1_output_loss: 0.7260 - y2_output_loss: 2.0969 - y1_output_root_mean_squared_error: 0.8524 - y2_output_root_mean_squared_error: 1.4543 - val_loss: 2.3498 - val_y1_output_loss: 0.4941 - val_y2_output_loss: 1.9948 - val_y1_output_root_mean_squared_error: 0.7140 - val_y2_output_root_mean_squared_error: 1.3564
# Epoch 119/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.0105 - y1_output_loss: 0.4275 - y2_output_loss: 1.5740 - y1_output_root_mean_squared_error: 0.6555 - y2_output_root_mean_squared_error: 1.2573 - val_loss: 2.7226 - val_y1_output_loss: 0.6748 - val_y2_output_loss: 2.0462 - val_y1_output_root_mean_squared_error: 0.8221 - val_y2_output_root_mean_squared_error: 1.4307
# Epoch 120/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1648 - y1_output_loss: 0.8011 - y2_output_loss: 2.3391 - y1_output_root_mean_squared_error: 0.8987 - y2_output_root_mean_squared_error: 1.5353 - val_loss: 4.7796 - val_y1_output_loss: 0.6838 - val_y2_output_loss: 4.0884 - val_y1_output_root_mean_squared_error: 0.8270 - val_y2_output_root_mean_squared_error: 2.0238
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7336 - y1_output_loss: 0.1515 - y2_output_loss: 0.5793 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.7634 - val_loss: 0.6527 - val_y1_output_loss: 0.1535 - val_y2_output_loss: 0.5068 - val_y1_output_root_mean_squared_error: 0.3917 - val_y2_output_root_mean_squared_error: 0.7066
# Epoch 462/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3523 - y1_output_loss: 0.1185 - y2_output_loss: 0.2313 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.4826 - val_loss: 0.7847 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.6024 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 0.7645
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3641 - y1_output_loss: 0.1095 - y2_output_loss: 0.2517 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.5038 - val_loss: 0.7868 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.6313 - val_y1_output_root_mean_squared_error: 0.4070 - val_y2_output_root_mean_squared_error: 0.7881
# Epoch 464/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3913 - y1_output_loss: 0.1137 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 0.7702 - val_y1_output_loss: 0.1698 - val_y2_output_loss: 0.5936 - val_y1_output_root_mean_squared_error: 0.4149 - val_y2_output_root_mean_squared_error: 0.7733
# Epoch 465/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3606 - y1_output_loss: 0.1168 - y2_output_loss: 0.2408 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.4928 - val_loss: 0.7464 - val_y1_output_loss: 0.1611 - val_y2_output_loss: 0.6041 - val_y1_output_root_mean_squared_error: 0.4059 - val_y2_output_root_mean_squared_error: 0.7627
# Epoch 466/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4374 - y1_output_loss: 0.1302 - y2_output_loss: 0.3037 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.5533 - val_loss: 0.6365 - val_y1_output_loss: 0.1531 - val_y2_output_loss: 0.4758 - val_y1_output_root_mean_squared_error: 0.3923 - val_y2_output_root_mean_squared_error: 0.6947
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3865 - y1_output_loss: 0.1121 - y2_output_loss: 0.2731 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.5233 - val_loss: 0.6810 - val_y1_output_loss: 0.1469 - val_y2_output_loss: 0.5354 - val_y1_output_root_mean_squared_error: 0.3860 - val_y2_output_root_mean_squared_error: 0.7294
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3454 - y1_output_loss: 0.1210 - y2_output_loss: 0.2214 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 0.6583 - val_y1_output_loss: 0.1368 - val_y2_output_loss: 0.5318 - val_y1_output_root_mean_squared_error: 0.3720 - val_y2_output_root_mean_squared_error: 0.7210
# Epoch 469/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4273 - y1_output_loss: 0.1161 - y2_output_loss: 0.3089 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.5570 - val_loss: 0.8580 - val_y1_output_loss: 0.1984 - val_y2_output_loss: 0.6507 - val_y1_output_root_mean_squared_error: 0.4476 - val_y2_output_root_mean_squared_error: 0.8109
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3577 - y1_output_loss: 0.1097 - y2_output_loss: 0.2484 - y1_output_root_mean_squared_error: 0.3327 - y2_output_root_mean_squared_error: 0.4970 - val_loss: 1.5960 - val_y1_output_loss: 0.1383 - val_y2_output_loss: 1.4865 - val_y1_output_root_mean_squared_error: 0.3761 - val_y2_output_root_mean_squared_error: 1.2060
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3528 - y1_output_loss: 0.1192 - y2_output_loss: 0.2335 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.4847 - val_loss: 0.9261 - val_y1_output_loss: 0.2528 - val_y2_output_loss: 0.6814 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 0.8207
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3311 - y1_output_loss: 0.1065 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3278 - y2_output_root_mean_squared_error: 0.4729 - val_loss: 0.6955 - val_y1_output_loss: 0.1506 - val_y2_output_loss: 0.5411 - val_y1_output_root_mean_squared_error: 0.3904 - val_y2_output_root_mean_squared_error: 0.7369
# Epoch 473/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3601 - y1_output_loss: 0.1091 - y2_output_loss: 0.2508 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.5006 - val_loss: 0.9934 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.8212 - val_y1_output_root_mean_squared_error: 0.4179 - val_y2_output_root_mean_squared_error: 0.9048
# Epoch 474/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3612 - y1_output_loss: 0.1093 - y2_output_loss: 0.2517 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 0.7889 - val_y1_output_loss: 0.1541 - val_y2_output_loss: 0.6248 - val_y1_output_root_mean_squared_error: 0.3965 - val_y2_output_root_mean_squared_error: 0.7947
# Epoch 475/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3659 - y1_output_loss: 0.1174 - y2_output_loss: 0.2482 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.4992 - val_loss: 0.6851 - val_y1_output_loss: 0.2072 - val_y2_output_loss: 0.4708 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_root_mean_squared_error: 0.6917
# Epoch 476/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.7052 - y1_output_loss: 0.2079 - y2_output_loss: 0.4930 - y1_output_root_mean_squared_error: 0.4572 - y2_output_root_mean_squared_error: 0.7044 - val_loss: 0.8815 - val_y1_output_loss: 0.2222 - val_y2_output_loss: 0.6510 - val_y1_output_root_mean_squared_error: 0.4761 - val_y2_output_root_mean_squared_error: 0.8093
# Epoch 477/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5284 - y1_output_loss: 0.1475 - y2_output_loss: 0.3804 - y1_output_root_mean_squared_error: 0.3848 - y2_output_root_mean_squared_error: 0.6167 - val_loss: 0.7095 - val_y1_output_loss: 0.1361 - val_y2_output_loss: 0.5621 - val_y1_output_root_mean_squared_error: 0.3734 - val_y2_output_root_mean_squared_error: 0.7551
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3339 - y1_output_loss: 0.1207 - y2_output_loss: 0.2164 - y1_output_root_mean_squared_error: 0.3408 - y2_output_root_mean_squared_error: 0.4666 - val_loss: 0.9841 - val_y1_output_loss: 0.1691 - val_y2_output_loss: 0.8557 - val_y1_output_root_mean_squared_error: 0.4162 - val_y2_output_root_mean_squared_error: 0.9005
# Epoch 479/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4300 - y1_output_loss: 0.1327 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3655 - y2_output_root_mean_squared_error: 0.5444 - val_loss: 0.7659 - val_y1_output_loss: 0.1429 - val_y2_output_loss: 0.6339 - val_y1_output_root_mean_squared_error: 0.3805 - val_y2_output_root_mean_squared_error: 0.7881
# Epoch 480/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3678 - y1_output_loss: 0.1091 - y2_output_loss: 0.2608 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.5090 - val_loss: 0.7564 - val_y1_output_loss: 0.1741 - val_y2_output_loss: 0.5641 - val_y1_output_root_mean_squared_error: 0.4208 - val_y2_output_root_mean_squared_error: 0.7611
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4318 - y1_output_loss: 0.1290 - y2_output_loss: 0.2992 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5494 - val_loss: 0.7238 - val_y1_output_loss: 0.1471 - val_y2_output_loss: 0.5765 - val_y1_output_root_mean_squared_error: 0.3869 - val_y2_output_root_mean_squared_error: 0.7577
# Epoch 482/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4701 - y1_output_loss: 0.1215 - y2_output_loss: 0.3532 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5918 - val_loss: 1.6179 - val_y1_output_loss: 0.3350 - val_y2_output_loss: 1.2643 - val_y1_output_root_mean_squared_error: 0.5819 - val_y2_output_root_mean_squared_error: 1.1311
# Epoch 483/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4372 - y1_output_loss: 0.1371 - y2_output_loss: 0.3006 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.5477 - val_loss: 0.8131 - val_y1_output_loss: 0.1625 - val_y2_output_loss: 0.6448 - val_y1_output_root_mean_squared_error: 0.4065 - val_y2_output_root_mean_squared_error: 0.8048
# Epoch 484/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4398 - y1_output_loss: 0.1254 - y2_output_loss: 0.3132 - y1_output_root_mean_squared_error: 0.3553 - y2_output_root_mean_squared_error: 0.5599 - val_loss: 0.8640 - val_y1_output_loss: 0.1469 - val_y2_output_loss: 0.7129 - val_y1_output_root_mean_squared_error: 0.3867 - val_y2_output_root_mean_squared_error: 0.8453
# Epoch 485/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3385 - y1_output_loss: 0.1068 - y2_output_loss: 0.2294 - y1_output_root_mean_squared_error: 0.3276 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.6596 - val_y1_output_loss: 0.1276 - val_y2_output_loss: 0.5253 - val_y1_output_root_mean_squared_error: 0.3602 - val_y2_output_root_mean_squared_error: 0.7279
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3085 - y1_output_loss: 0.1020 - y2_output_loss: 0.2077 - y1_output_root_mean_squared_error: 0.3199 - y2_output_root_mean_squared_error: 0.4541 - val_loss: 0.8879 - val_y1_output_loss: 0.1449 - val_y2_output_loss: 0.7773 - val_y1_output_root_mean_squared_error: 0.3843 - val_y2_output_root_mean_squared_error: 0.8604
# Epoch 487/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4026 - y1_output_loss: 0.1093 - y2_output_loss: 0.2940 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.4706 - val_y1_output_loss: 0.3045 - val_y2_output_loss: 1.1452 - val_y1_output_root_mean_squared_error: 0.5533 - val_y2_output_root_mean_squared_error: 1.0791
# Epoch 488/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4461 - y1_output_loss: 0.1226 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.5680 - val_loss: 0.7023 - val_y1_output_loss: 0.1821 - val_y2_output_loss: 0.5105 - val_y1_output_root_mean_squared_error: 0.4313 - val_y2_output_root_mean_squared_error: 0.7185
# Epoch 489/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.6791 - y1_output_loss: 0.1588 - y2_output_loss: 0.5211 - y1_output_root_mean_squared_error: 0.3975 - y2_output_root_mean_squared_error: 0.7219 - val_loss: 0.7678 - val_y1_output_loss: 0.1753 - val_y2_output_loss: 0.5827 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 0.7684
# Epoch 490/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4522 - y1_output_loss: 0.1251 - y2_output_loss: 0.3286 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5723 - val_loss: 0.6764 - val_y1_output_loss: 0.1417 - val_y2_output_loss: 0.5390 - val_y1_output_root_mean_squared_error: 0.3779 - val_y2_output_root_mean_squared_error: 0.7304
# Epoch 491/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8372 - y1_output_loss: 0.1767 - y2_output_loss: 0.6542 - y1_output_root_mean_squared_error: 0.4215 - y2_output_root_mean_squared_error: 0.8121 - val_loss: 0.6687 - val_y1_output_loss: 0.1452 - val_y2_output_loss: 0.5135 - val_y1_output_root_mean_squared_error: 0.3843 - val_y2_output_root_mean_squared_error: 0.7218
# Epoch 492/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3650 - y1_output_loss: 0.1145 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5017 - val_loss: 1.2837 - val_y1_output_loss: 0.2999 - val_y2_output_loss: 0.9802 - val_y1_output_root_mean_squared_error: 0.5482 - val_y2_output_root_mean_squared_error: 0.9915
# Epoch 493/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3427 - y1_output_loss: 0.1103 - y2_output_loss: 0.2315 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.4814 - val_loss: 1.4524 - val_y1_output_loss: 0.3965 - val_y2_output_loss: 1.0327 - val_y1_output_root_mean_squared_error: 0.6321 - val_y2_output_root_mean_squared_error: 1.0261
# Epoch 494/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6353 - y1_output_loss: 0.1718 - y2_output_loss: 0.4769 - y1_output_root_mean_squared_error: 0.4154 - y2_output_root_mean_squared_error: 0.6802 - val_loss: 2.8267 - val_y1_output_loss: 0.2133 - val_y2_output_loss: 2.6625 - val_y1_output_root_mean_squared_error: 0.4644 - val_y2_output_root_mean_squared_error: 1.6159
# Epoch 495/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6333 - y1_output_loss: 0.1527 - y2_output_loss: 0.4760 - y1_output_root_mean_squared_error: 0.3920 - y2_output_root_mean_squared_error: 0.6926 - val_loss: 0.8596 - val_y1_output_loss: 0.1696 - val_y2_output_loss: 0.6960 - val_y1_output_root_mean_squared_error: 0.4139 - val_y2_output_root_mean_squared_error: 0.8296
# Epoch 496/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.6870 - y1_output_loss: 0.1575 - y2_output_loss: 0.5321 - y1_output_root_mean_squared_error: 0.3978 - y2_output_root_mean_squared_error: 0.7272 - val_loss: 1.1395 - val_y1_output_loss: 0.3373 - val_y2_output_loss: 0.7823 - val_y1_output_root_mean_squared_error: 0.5822 - val_y2_output_root_mean_squared_error: 0.8947
# Epoch 497/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3805 - y1_output_loss: 0.1167 - y2_output_loss: 0.2657 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5126 - val_loss: 1.2078 - val_y1_output_loss: 0.3143 - val_y2_output_loss: 0.8697 - val_y1_output_root_mean_squared_error: 0.5679 - val_y2_output_root_mean_squared_error: 0.9409
# Epoch 498/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3374 - y1_output_loss: 0.1185 - y2_output_loss: 0.2191 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.4680 - val_loss: 0.8644 - val_y1_output_loss: 0.1776 - val_y2_output_loss: 0.6876 - val_y1_output_root_mean_squared_error: 0.4229 - val_y2_output_root_mean_squared_error: 0.8280
# Epoch 499/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3762 - y1_output_loss: 0.1260 - y2_output_loss: 0.2476 - y1_output_root_mean_squared_error: 0.3558 - y2_output_root_mean_squared_error: 0.4996 - val_loss: 0.8140 - val_y1_output_loss: 0.2027 - val_y2_output_loss: 0.6084 - val_y1_output_root_mean_squared_error: 0.4563 - val_y2_output_root_mean_squared_error: 0.7783
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 1.0523 - y1_output_loss: 0.2479 - y2_output_loss: 0.7959 - y1_output_root_mean_squared_error: 0.5001 - y2_output_root_mean_squared_error: 0.8956 - val_loss: 0.8500 - val_y1_output_loss: 0.1969 - val_y2_output_loss: 0.6519 - val_y1_output_root_mean_squared_error: 0.4477 - val_y2_output_root_mean_squared_error: 0.8059

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.8500 - y1_output_loss: 0.2021 - y2_output_loss: 0.6584 - y1_output_root_mean_squared_error: 0.4477 - y2_output_root_mean_squared_error: 0.8059
# Loss = 0.84995597368711, Y1_loss = 0.20209738612174988, Y1_mse = 0.44774001836776733, Y2_loss = 0.6584032773971558, Y2_mse = 0.8059062361717224

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
